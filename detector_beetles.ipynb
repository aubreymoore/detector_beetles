# %% [markdown]
# # Detector Beetle Field Trial - Data Analysis

# %%
import pandas as pd
import fnmatch
import os
import gpxpy
import re

# %% [markdown]
# ## End Points
#
# Data source is a CSV text file, **detector_beetles1.csv** with the following fields:
#
# * **beetle_id** Code engraved on beetle's elytrum
# * **frequency** frequency (MHz) of radio transmitter glued to beetle's pronotum
# * **rel_site** release site; Asan [13.473904, 144.708537]; Yigo [13.531333, 144.872750]
# * **Notes** tracking notes
# * **lat2** latitude of final observation (decimal degrees)
# * **lon2** longitude of final observation (decimal degrees)
# * **t2** timestamp of final observation (ChST)
# * **extended_track_bearing** direction of travel from the final observation point (direct observation or radio direction finding)
# * **end_point_located**
# * **in_tree** TRUE if end point is in a tree; determined visually or by radio direction finding
# * **breeding_site** TRUE if otjer CRB present
# * **flight_test_date** date on which beetle was flight tested and measured (ChST)
# * **Length** lengthe of elytra (mm)
# * **Width** width across elytra (mm)
# * **Weight** mass (g)

# %%
df_endpoints = pd.read_csv('detector_beetles1.csv')
df_endpoints.sort(columns=['frequency'], inplace=True) # Sort by frequency
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', 1000)
df_endpoints
# Out:
#     beetle_id  frequency rel_site  \
# 0        2968    148.641     Asan
# 1        2977    148.671     Asan
# 2        2991    148.693     Asan
# 3        2981    148.703     Asan
# 4        2971    148.732     Yigo
# 5        2929    148.752      NaN
# 6        2985    148.764     Asan
# 7        2963    148.782     Yigo
# 8        2952    148.792     Yigo
# 9        2978    148.820     Yigo
# 10       2982    148.851     Yigo
# 11       2987    148.873     Asan
# 12       2970    148.873     Yigo
# 13       2931    148.902     Yigo
# 14       2958    148.932     Yigo
# 15       2974    148.963     Yigo
# 16       2976    148.972     Asan
# 17       2962    148.992     Asan
# 18       2980    164.032     Asan
# 19       2989    164.058     Asan
# 20       2951    164.082      NaN
# 21       2967    164.107     Asan
# 22       2972    164.132     Yigo
# 23       2964    164.157     Asan
# 24       2988    164.182     Asan
# 25       2949    164.208     Yigo
# 26       2979    164.232     Asan
# 27       2983    164.258     Asan
# 28       2975    164.282     Asan
# 29       2969    164.307      NaN
# 30       2966    164.333     Yigo
# 31       2965    164.357     Asan
# 32       2944    164.382     Asan
# 33       2973    164.409     Yigo
#
#                                                                                     Notes  \
# 0                              weak signal coming from swamp across from Asan Park; swamp
# 1                                              Found at base of coco tree; just off beach
# 2                                                                     Lost west over hill
# 3                                                           Lost west over hill; no track
# 4                                                          top of coconut tree adjust GPS
# 5                                                                          lost; no track
# 6                                                              out of range; towards road
# 7                                                     under trailer in the dirt; no track
# 8                                                beetle in breadfruit tree; 2952?; wooded
# 9                                                         faint signal in woods; no track
# 10                                              under barrel #12, saw beetle, left beetle
# 11                                                                        base of coconut
# 12  found beetle in soil, transmitter ~20 cm away, retrieved beetle; transmitter reused??
# 13                                        out of range, toward highschool? East; no track
# 14                                             in coconut tree with 6+ bore holes; wooded
# 15                                         edge of dense woods, up high; wooded; no track
# 16                                            Damaged wing, lost west over hill; no track
# 17                                                                            Coconut top
# 18                                                             in damaged coco tree crown
# 19                                                               Same place in coco crown
# 20                                                      Lost east; no coordnates recorded
# 21                                                             in damaged coco tree crown
# 22                                                                  lost into dense brush
# 23                           on top of large coco tree on beach across the hill Asan Park
# 24                                            Found beetl under barrel trap. breedin site
# 25                                        in heavily damaged coco tree over fence; wooded
# 26                                       Lost at indicated coordinates; went out of range
# 27                                                   In or around base of small coco tree
# 28                                                                On top of big coco tree
# 29                                                                                    NaN
# 30                                         In coco tree crown in private property; wooded
# 31                                                        towards tall grass only up high
# 32                                                                      Asan; Did not fly
# 33                                        in brush line around base of small papy; wooded
#
#          lat2        lon2                   t2  extended_track_bearing  \
# 0   13.473933  144.708633     2015-08-11 09:18                  180.00
# 1   13.474933  144.708750           2015-08-11                     NaN
# 2   13.472575  144.707141  2015-08-12 19:58:50                  270.00
# 3         NaN         NaN                  NaN                  270.00
# 4   13.535104  144.873882     2015-08-12 11:00                     NaN
# 5         NaN         NaN           2015-08-10                     NaN
# 6   13.473374  144.708416     2015-08-10 21:01                  180.00
# 7   13.529393  144.870394     2015-08-12 12:36                     NaN
# 8   13.530583  144.872400     2015-08-10 09:30                     NaN
# 9   13.529850  144.872300     2015-08-11 20:58                  196.44
# 10  13.532033  144.873467     2015-08-12 09:18                     NaN
# 11  13.474723  144.708906           2015-08-13                     NaN
# 12  13.532250  144.870383     2015-08-12 10:00                     NaN
# 13        NaN         NaN           2015-08-10                  135.00
# 14  13.530546  144.870442     2015-08-11 11:00                     NaN
# 15  13.529167  144.872683     2015-08-11 19:31                  181.72
# 16        NaN         NaN                  NaN                  270.00
# 17  13.473946  144.708144           2015-06-13                     NaN
# 18  13.473150  144.708310     2015-08-11 08:56                     NaN
# 19  13.473707  144.711533                  NaN                     NaN
# 20        NaN         NaN                  NaN                   90.00
# 21  13.473160  144.708330     2015-08-11 08:54                     NaN
# 22  13.532510  144.871660     2015-08-12 11:07                  318.00
# 23  13.471210  144.706360           2015-08-11                     NaN
# 24  13.475751  144.707832                  NaN                     NaN
# 25  13.533230  144.873760     2015-08-12 09:00                     NaN
# 26  13.474440  144.708450           2015-08-10                  351.03
# 27  13.473650  144.712750     2015-08-11 09:07                     NaN
# 28  13.473145  144.708264                  NaN                     NaN
# 29        NaN         NaN                  NaN                     NaN
# 30  13.529730  144.871570     2015-08-12 11:43                     NaN
# 31  13.472615  144.707277     2015-08-13 11:20                  180.00
# 32        NaN         NaN                  NaN                     NaN
# 33  13.531440  144.871610     2015-08-11 20:32                     NaN
#
#    end_point_located in_tree breeding_site flight_test_date Sex  Length  \
# 0              False     NaN           NaN       2015-08-10   f   21.17
# 1               True   False           NaN       2015-08-10   f   21.83
# 2              False     NaN           NaN       2015-08-11   m   25.86
# 3              False     NaN           NaN       2015-08-10   f   24.94
# 4               True    True           NaN       2015-08-10   m   22.36
# 5              False     NaN           NaN       2015-08-05   f   25.41
# 6              False     NaN           NaN       2015-08-10   f   22.80
# 7               True   False           NaN       2015-08-10   m   20.33
# 8               True    True          True       2015-08-05   f   24.07
# 9              False     NaN           NaN       2015-08-10   m   25.22
# 10              True   False           NaN       2015-08-10   m   23.47
# 11              True   False           NaN       2015-08-11   f   23.31
# 12              True   False           NaN       2015-08-10   m   21.60
# 13             False     NaN           NaN       2015-08-05   m   24.36
# 14              True    True           NaN       2015-08-05   f   25.76
# 15             False    True           NaN       2015-08-10   m   22.59
# 16             False     NaN           NaN       2015-08-10   m   23.63
# 17              True    True           NaN       2015-08-10   m   26.73
# 18              True    True           NaN       2015-08-10   m   25.96
# 19              True    True           NaN       2015-08-11   m   24.97
# 20             False     NaN           NaN       2015-08-05   f   24.90
# 21              True    True           NaN       2015-08-10   f   23.40
# 22             False     NaN           NaN       2015-08-10   f   25.31
# 23              True    True           NaN       2015-08-10   f   24.03
# 24              True   False          True       2015-08-11   f   26.41
# 25              True    True           NaN       2015-08-05   m   26.15
# 26             False   False           NaN       2015-08-10   m   24.31
# 27              True   False           NaN       2015-08-10   f   22.07
# 28              True    True           NaN       2015-08-10   m   23.82
# 29             False     NaN           NaN       2015-08-10   f   24.19
# 30              True    True           NaN       2015-08-10   f   24.01
# 31             False    True           NaN       2015-08-10   f   22.13
# 32               NaN     NaN           NaN       2015-08-05   m   22.93
# 33              True   False           NaN       2015-08-10   m   21.25
#
#     Width  Weight
# 0   16.47   2.641
# 1   16.99   3.622
# 2   20.63   5.774
# 3   18.96   5.206
# 4   17.55   3.087
# 5   20.29   4.220
# 6   18.07   4.017
# 7   16.28   3.179
# 8   18.67   4.229
# 9   20.15   5.213
# 10  18.75   4.672
# 11  18.31   3.758
# 12  17.02   3.411
# 13  18.60   4.367
# 14  19.16   5.009
# 15  17.97   3.562
# 16  18.40   3.803
# 17  21.19   6.041
# 18  20.97   5.951
# 19  19.96   5.329
# 20  19.14   5.025
# 21  18.15   4.208
# 22  19.82   4.433
# 23  18.71   4.211
# 24  21.01   6.439
# 25  20.90   5.942
# 26  19.01   4.563
# 27  17.35   4.126
# 28  18.39   3.910
# 29  19.10   4.811
# 30  18.94   4.379
# 31  17.13   2.989
# 32  17.73   2.881
# 33  16.50   3.289

# %% [markdown]
# ## Data Mine All GPX Files for Waypoints of Tracked Beetles
#
# Parse every **gpx** file contained in the ~/Dropbox/detectorBeetles folder and subfolders and extract data from waypoints in which a radio transmitter frequency ['148.???', '164.???'] is part of the **comment**
# field. Waypoints are simulated for release sites and appended to the dataframe.

# %%
wp_list = []
for root, dirnames, filenames in os.walk('..'):
    for filename in fnmatch.filter(filenames, '*.gpx'):
        filepath = os.path.join(root, filename)      
        gpx_file = open(filepath).read()   
        gpx = gpxpy.parse(gpx_file)
        for wp in gpx.waypoints:
            s = wp.comment
            if s:
                if '148.' in s or '164.' in s:
                    frequency = re.findall('\d+.?\d+', s)[0] # Extract frequency from comment string
                    wp_list.append({'frequency':frequency, 'comment':wp.comment, 'filepath':filepath, 'name':wp.name, 'time':wp.time,
                                   'latitude':wp.latitude, 'longitude':wp.longitude})
df_waypoints = pd.DataFrame(wp_list)
df_waypoints.time = df_waypoints.time + pd.Timedelta(hours=10) # Add 10 h to convert from UTC to ChST

# Add waypoints for release sites.

simulated_waypoints = []
for i, row in df_waypoints.drop_duplicates('frequency').iterrows():
    if row.latitude > 13.5:
        rel_lat = 13.531333
        rel_lon = 144.872750
    else:
        rel_lat = 13.473904
        rel_lon = 144.708537
    simulated_waypoint = {'comment':'release point', 'frequency':row.frequency, 'latitude':rel_lat, 
                          'longitude':rel_lon, 'time':'2015-08-01 00:00:00'}
    simulated_waypoints.append(simulated_waypoint)
df_waypoints = df_waypoints.append(simulated_waypoints)
df_waypoints = df_waypoints[['frequency', 'comment', 'filepath', 'name', 'latitude', 'longitude', 'time']] # Reorder columns
df_waypoints.sort(columns=['frequency', 'time'], inplace=True) # Sort by frequency, time
pd.set_option('display.max_rows', 100)
df_waypoints
# Out:
#    frequency                                             comment  \
# 11   148.671                                       release point
# 21   148.671                                  148.671 Under tree
# 29   148.671                        148.671 No beetle just trans
# 12   148.693                                       release point
# 24   148.693                                     148.693 Up hill
# 10   148.732                                       release point
# 33   148.732                                  148.732 Over fense
# 20   148.732                  148.732 Top of coconut tree adjust
# 7    148.764                                       release point
# 17   148.764                   148.764 Out of range towards road
# 13   148.792                                       release point
# 25   148.792                                   148.792 Down hill
# 8    148.851                                       release point
# 34   148.851                                  148.851 In trap 12
# 18   148.851                                148.851 Under barrel
# 31   148.851                                  148.851 Lost trans
# 9    148.873                                       release point
# 32   148.873                                  148.873 Over fense
# 19   148.873                            148.873 Drop t on ground
# 22   148.873                                     148.873 Up hill
# 23   148.873                             148.873 Base of coconut
# 0    148.932                                       release point
# 0    148.932                                  148.932 In coconut
# 16   148.932                                  148.932 In coconut
# 4    148.992                                       release point
# 26   148.992                                   148.992 Down hill
# 5    148.992                   148.992 Top coconut after up hill
# 27   148.992                    148.992 Up coconut after up hill
# 28   148.992                                 148.992 Coconut top
# 1    164.132                                       release point
# 15   164.132  164.132 Barely, 12-08 Walked into brush couldnt kp
# 1    164.132                            164.132 Lost around here
# 2    164.157                                       release point
# 12   164.157                  164.157 On top of rock 5 bars gain
# 13   164.157    164.157 On top of hill towards other beach palms
# 14   164.157               164.157 in a trio of small palm trees
# 2    164.157                                   164.157 Same spot
# 3    164.157              164.157 Not on trio but on.top of coco
# 5    164.282                                       release point
# 6    164.282                     164.282 On top of big coco tree
# 7    164.282                                   164.282 Same spot
# 3    164.357                                       release point
# 4    164.357      164.357 From up top signal across st full gain
# 8    164.357     164.357 Signal coming from across prk access rd
# 9    164.357       164.357 Signal from on hill but not on ground
# 11   164.357        164.357 Towards tall grass only from up high
# 6    164.380                                       release point
# 10   164.380                    164.380 Under deadtree across st
# 14   164.382                                       release point
# 30   164.382                                      164.382 No fly
#
#                                                    filepath  name   latitude  \
# 11                                                      NaN   NaN  13.473904
# 21   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   144  13.474914
# 29   ../gpx by device by day/crb003/Waypoints_13-AUG-15.gpx   152  13.474930
# 12                                                      NaN   NaN  13.473904
# 24   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   147  13.472575
# 10                                                      NaN   NaN  13.531333
# 33   ../gpx by device by day/crb003/Waypoints_11-AUG-15.gpx   139  13.533517
# 20   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   143  13.534695
# 7                                                       NaN   NaN  13.473904
# 17   ../gpx by device by day/crb003/Waypoints_10-AUG-15.gpx  Uuuu  13.473374
# 13                                                      NaN   NaN  13.473904
# 25   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   148  13.472583
# 8                                                       NaN   NaN  13.531333
# 34   ../gpx by device by day/crb003/Waypoints_11-AUG-15.gpx   140  13.532034
# 18   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   141  13.532032
# 31   ../gpx by device by day/crb003/Waypoints_13-AUG-15.gpx   154  13.532036
# 9                                                       NaN   NaN  13.531333
# 32   ../gpx by device by day/crb003/Waypoints_11-AUG-15.gpx   138  13.532304
# 19   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   142  13.532258
# 22   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   145  13.475064
# 23   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   146  13.474700
# 0                                                       NaN   NaN  13.473904
# 0   ../gis-2015-08-08/Garmin001/GPX/Waypoints_08-AUG-15.gpx   122  13.492996
# 16   ../gpx by device by day/crb001/Waypoints_08-AUG-15.gpx   122  13.492996
# 4                                                       NaN   NaN  13.473904
# 26   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   149  13.473563
# 5    ../gpx by device by day/crb006/Waypoints_12-AUG-15.gpx   132  13.473998
# 27   ../gpx by device by day/crb003/Waypoints_12-AUG-15.gpx   150  13.474004
# 28   ../gpx by device by day/crb003/Waypoints_13-AUG-15.gpx   151  13.473946
# 1                                                       NaN   NaN  13.531333
# 15   ../gpx by device by day/crb006/Waypoints_11-AUG-15.gpx   126  13.531320
# 1    ../gpx by device by day/crb006/Waypoints_12-AUG-15.gpx   127  13.532509
# 2                                                       NaN   NaN  13.531333
# 12   ../gpx by device by day/crb006/Waypoints_11-AUG-15.gpx   122  13.474407
# 13   ../gpx by device by day/crb006/Waypoints_11-AUG-15.gpx   123  13.472294
# 14   ../gpx by device by day/crb006/Waypoints_11-AUG-15.gpx   124  13.471207
# 2    ../gpx by device by day/crb006/Waypoints_12-AUG-15.gpx   128  13.532386
# 3    ../gpx by device by day/crb006/Waypoints_12-AUG-15.gpx   129  13.532386
# 5                                                       NaN   NaN  13.473904
# 6    ../gpx by device by day/crb006/Waypoints_12-AUG-15.gpx   133  13.473145
# 7    ../gpx by device by day/crb006/Waypoints_13-AUG-15.gpx   134  13.474748
# 3                                                       NaN   NaN  13.473904
# 4    ../gpx by device by day/crb006/Waypoints_12-AUG-15.gpx   130  13.471225
# 8    ../gpx by device by day/crb006/Waypoints_13-AUG-15.gpx   135  13.471760
# 9    ../gpx by device by day/crb006/Waypoints_13-AUG-15.gpx   136  13.471760
# 11   ../gpx by device by day/crb006/Waypoints_13-AUG-15.gpx   139  13.472615
# 6                                                       NaN   NaN  13.473904
# 10   ../gpx by device by day/crb006/Waypoints_13-AUG-15.gpx   138  13.472615
# 14                                                      NaN   NaN  13.473904
# 30   ../gpx by device by day/crb003/Waypoints_13-AUG-15.gpx   153  13.473975
#
#      longitude                 time
# 11  144.708537  2015-08-01 00:00:00
# 21  144.708741  2015-08-12 16:31:51
# 29  144.708739  2015-08-13 10:00:17
# 12  144.708537  2015-08-01 00:00:00
# 24  144.707141  2015-08-12 19:58:50
# 10  144.872750  2015-08-01 00:00:00
# 33  144.871667  2015-08-11 20:10:48
# 20  144.873841  2015-08-12 10:57:45
# 7   144.708537  2015-08-01 00:00:00
# 17  144.708416  2015-08-10 21:01:26
# 13  144.708537  2015-08-01 00:00:00
# 25  144.707267  2015-08-12 20:01:24
# 8   144.872750  2015-08-01 00:00:00
# 34  144.873406  2015-08-11 20:29:19
# 18  144.873480  2015-08-12 09:18:23
# 31  144.873400  2015-08-13 13:39:49
# 9   144.872750  2015-08-01 00:00:00
# 32  144.870860  2015-08-11 19:27:25
# 19  144.870622  2015-08-12 10:00:15
# 22  144.707886  2015-08-12 19:14:33
# 23  144.708970  2015-08-12 19:30:09
# 0   144.708537  2015-08-01 00:00:00
# 0   144.775814  2015-08-08 10:33:00
# 16  144.775814  2015-08-08 10:33:00
# 4   144.708537  2015-08-01 00:00:00
# 26  144.707217  2015-08-12 20:39:10
# 5   144.708077  2015-08-12 20:47:42
# 27  144.708120  2015-08-12 20:49:01
# 28  144.708144  2015-08-13 09:02:38
# 1   144.872750  2015-08-01 00:00:00
# 15  144.872727  2015-08-11 20:41:26
# 1   144.871666  2015-08-12 11:07:04
# 2   144.872750  2015-08-01 00:00:00
# 12  144.708445  2015-08-11 09:08:36
# 13  144.707195  2015-08-11 09:17:53
# 14  144.706364  2015-08-11 09:36:52
# 2   144.871812  2015-08-12 16:46:22
# 3   144.871812  2015-08-12 16:50:50
# 5   144.708537  2015-08-01 00:00:00
# 6   144.708264  2015-08-12 21:02:54
# 7   144.708251  2015-08-13 09:05:36
# 3   144.708537  2015-08-01 00:00:00
# 4   144.706310  2015-08-12 17:09:57
# 8   144.707957  2015-08-13 09:21:10
# 9   144.707957  2015-08-13 09:26:53
# 11  144.707277  2015-08-13 11:20:10
# 6   144.708537  2015-08-01 00:00:00
# 10  144.707277  2015-08-13 11:10:15
# 14  144.708537  2015-08-01 00:00:00
# 30  144.708587  2015-08-13 10:08:47

# %%
s = 'frequency|track\n'
for freq in df_waypoints.frequency.unique():
    s += '{}|LINESTRING('.format(freq)
    df = df_waypoints[df_waypoints.frequency==freq]
    for i, row in df.iterrows():
        s += '{} {},'.format(row.longitude, row.latitude)
    s = s[:-1] + ')\n'
print(s) 
with open("track2.csv", "w") as text_file:
    text_file.write(s)
# Out:
# frequency|track
# 148.671|LINESTRING(144.708537 13.473904,144.708741 13.474914,144.708739 13.47493)
# 148.693|LINESTRING(144.708537 13.473904,144.707141 13.472575)
# 148.732|LINESTRING(144.87275 13.531333,144.871667 13.533517,144.873841 13.534695)
# 148.764|LINESTRING(144.708537 13.473904,144.708415959 13.4733739961)
# 148.792|LINESTRING(144.708537 13.473904,144.707267 13.472583)
# 148.851|LINESTRING(144.87275 13.531333,144.873406 13.532034,144.87348 13.532032,144.8734 13.532036)
# 148.873|LINESTRING(144.87275 13.531333,144.87086 13.532304,144.870622 13.532258,144.707886 13.475064,144.70897 13.4747)
# 148.932|LINESTRING(144.708537 13.473904,144.775814 13.492996,144.775814 13.492996)
# 148.992|LINESTRING(144.708537 13.473904,144.707217 13.473563,144.708077 13.473998,144.70812 13.474004,144.708144 13.473946)
# 164.132|LINESTRING(144.87275 13.531333,144.872727 13.53132,144.871666 13.532509)
# 164.157|LINESTRING(144.87275 13.531333,144.708445 13.474407,144.707195 13.472294,144.706364 13.471207,144.871812 13.532386,144.871812 13.532386)
# 164.282|LINESTRING(144.708537 13.473904,144.708264 13.473145,144.708251 13.474748)
# 164.357|LINESTRING(144.708537 13.473904,144.70631 13.471225,144.707957 13.47176,144.707957 13.47176,144.707277 13.472615)
# 164.380|LINESTRING(144.708537 13.473904,144.707277 13.472615)
# 164.382|LINESTRING(144.708537 13.473904,144.708587 13.473975)

# %%
import pyproj
import math
import random

wgs84=pyproj.Proj("+init=EPSG:4326") # LatLon with WGS84 datum used by GPS units and Google Earth
utm55n=pyproj.Proj("+init=EPSG:32655") # UTM coords, zone 55N, WGS84 datum

def extended_track(longitude, latitude, distance, bearing, bearing_jitter=0):
    """ Returns a track extended from a point for a given distance in a given direction.
    longitude, latitude: starting point in WGS84
    distance: distance to extend track in meters
    angle: angle in compass degrees (east = 90)
    angle_jitter: range of a uniform random number to be added or subracted from angle;
        for eaxmple, if angle=90 and angle_jitter=0.5, track will have an angle between 89.5 and 90.5
        
    Returns a track as a LINESTRING
    """
    x, y = pyproj.transform(wgs84, utm55n, longitude, latitude)
    if bearing_jitter > 0:
        bearing = random.uniform(bearing-bearing_jitter, bearing+bearing_jitter)
    angle = math.radians(90.0 - bearing) # angle in radians
    x_final, y_final = (x + distance * math.cos(angle), y + distance * math.sin(angle))
    longitude_final, latitude_final = pyproj.transform(utm55n, wgs84, x_final, y_final) # Convert back to lnn/lat
    return longitude_final, latitude_final

#extended_track(144.70901, 13.47140, 500, 90, 0.5)

def get_bearing(lat1, lon1, lat2, lon2):
    """ Returns bearing between two geographical coordinates in decimal degrees
    """
    startLat = math.radians(lat1)
    startLong = math.radians(lon1)
    endLat = math.radians(lat2)
    endLong = math.radians(lon2)
    dLong = endLong - startLong
    dPhi = math.log(math.tan(endLat/2.0+math.pi/4.0)/math.tan(startLat/2.0+math.pi/4.0))
    if abs(dLong) > math.pi:
         if dLong > 0.0:
             dLong = -(2.0 * math.pi - dLong)
         else:
             dLong = (2.0 * math.pi + dLong)
    bearing = (math.degrees(math.atan2(dLong, dPhi)) + 360.0) % 360.0;
    return bearing

#get_bearing(43.682213, -70.450696, 43.682194, -70.450769)
# 250.20613449

# %% [raw]
# def continue_track():
#     """ If 'cont' is entered in the extended_track_bearing field,
#     replace with bearing between release point and last waypoint
#     """
#
# for i, r in df_endpoints.iterrows():
#     if r.extended_track_bearing == 'cont':
#         if r.rel_site == 'Asan':
#             lon1, lat1 = 144.708537, 13.473904
#         elif r.rel_site == 'Yigo':
#             lon1, lat1 = 144.87275, 13.531333
#         bearing = get_bearing(lat1, lon1, r.lat2, r.lon2)
#         df_endpoints.set_value(i, 'extended_track_bearing', bearing)
# df_endpoints
# df_endpoints.to_csv('detector_beetles.csv')

# %%
import re

def parse_linestring(linestring):
    """ Returns coordinates as a list of tuples
    """
    coord_list = []
    for line in s.split(','):
        coord = re.findall(r'[+-]?[0-9.]+', line)
        coord = tuple(coord)
        coord_list.append(coord)
    return coord_list

s = 'LINESTRING(144.708741 13.473904, 144.708537 13.473904)'    
parse_linestring(s)
# Out:
# [('144.708741', '13.473904'), ('144.708537', '13.473904')]

# %%
import simplekml

kml = simplekml.Kml()

track_style = simplekml.Style()
track_style.linestyle.color = simplekml.Color.yellow
track_style.linestyle.width = 4

extended_track_style = simplekml.Style()
extended_track_style.linestyle.color = simplekml.Color.orange
extended_track_style.linestyle.width = 2

# Tracks

for i, row in df_endpoints.iterrows():
    if row.rel_site == 'Asan':
        coord1 = (144.708537, 13.473904)
    elif row.rel_site == 'Yigo':
        coord1 = (144.87275, 13.531333)
    else:
        continue

    if not pd.isnull(row.lon2) and not pd.isnull(row.lat2):
        coord2 = (row.lon2, row.lat2)
    else:
        coord2 = coord1
        
    ls = kml.newlinestring(name=str(row.beetle_id), coords=[coord1, coord2])
    ls.style = track_style
    
    if not pd.isnull(row.extended_track_bearing):
        extended_coord = extended_track(coord2[0], coord2[1], 500, row.extended_track_bearing, 5.0)
        ls = kml.newlinestring(coords=[coord2, extended_coord])
        ls.style = extended_track_style  
        
for i, row in df_endpoints.iterrows():
    if not pd.isnull(row.lon2) and not pd.isnull(row.lat2):
        pnt = kml.newpoint(name=str(row.beetle_id), coords=[(row.lon2, row.lat2)])      

kml.save('tracks.kml')

# %%
df_endpoints
# Out:
#     beetle_id  frequency rel_site  \
# 0        2968    148.641     Asan
# 1        2977    148.671     Asan
# 2        2991    148.693     Asan
# 3        2981    148.703     Asan
# 4        2971    148.732     Yigo
# 5        2929    148.752      NaN
# 6        2985    148.764     Asan
# 7        2963    148.782     Yigo
# 8        2952    148.792     Yigo
# 9        2978    148.820     Yigo
# 10       2982    148.851     Yigo
# 11       2987    148.873     Asan
# 12       2970    148.873     Yigo
# 13       2931    148.902     Yigo
# 14       2958    148.932     Yigo
# 15       2974    148.963     Yigo
# 16       2976    148.972     Asan
# 17       2962    148.992     Asan
# 18       2980    164.032     Asan
# 19       2989    164.058     Asan
# 20       2951    164.082      NaN
# 21       2967    164.107     Asan
# 22       2972    164.132     Yigo
# 23       2964    164.157     Asan
# 24       2988    164.182     Asan
# 25       2949    164.208     Yigo
# 26       2979    164.232     Asan
# 27       2983    164.258     Asan
# 28       2975    164.282     Asan
# 29       2969    164.307      NaN
# 30       2966    164.333     Yigo
# 31       2965    164.357     Asan
# 32       2944    164.382     Asan
# 33       2973    164.409     Yigo
#
#                                                                                     Notes  \
# 0                              weak signal coming from swamp across from Asan Park; swamp
# 1                                              Found at base of coco tree; just off beach
# 2                                                                     Lost west over hill
# 3                                                           Lost west over hill; no track
# 4                                                          top of coconut tree adjust GPS
# 5                                                                          lost; no track
# 6                                                              out of range; towards road
# 7                                                     under trailer in the dirt; no track
# 8                                                beetle in breadfruit tree; 2952?; wooded
# 9                                                         faint signal in woods; no track
# 10                                              under barrel #12, saw beetle, left beetle
# 11                                                                        base of coconut
# 12  found beetle in soil, transmitter ~20 cm away, retrieved beetle; transmitter reused??
# 13                                        out of range, toward highschool? East; no track
# 14                                             in coconut tree with 6+ bore holes; wooded
# 15                                         edge of dense woods, up high; wooded; no track
# 16                                            Damaged wing, lost west over hill; no track
# 17                                                                            Coconut top
# 18                                                             in damaged coco tree crown
# 19                                                               Same place in coco crown
# 20                                                      Lost east; no coordnates recorded
# 21                                                             in damaged coco tree crown
# 22                                                                  lost into dense brush
# 23                           on top of large coco tree on beach across the hill Asan Park
# 24                                            Found beetl under barrel trap. breedin site
# 25                                        in heavily damaged coco tree over fence; wooded
# 26                                       Lost at indicated coordinates; went out of range
# 27                                                   In or around base of small coco tree
# 28                                                                On top of big coco tree
# 29                                                                                    NaN
# 30                                         In coco tree crown in private property; wooded
# 31                                                        towards tall grass only up high
# 32                                                                      Asan; Did not fly
# 33                                        in brush line around base of small papy; wooded
#
#          lat2        lon2                   d2           t2  \
# 0   13.473933  144.708633            11-Aug-15         9:18
# 1   13.474933  144.708750            11-Aug-15          NaN
# 2   13.472575  144.707141  2015-08-12 19:58:50          NaN
# 3         NaN         NaN                  NaN          NaN
# 4   13.535104  144.873882            12-Aug-15        11:00
# 5         NaN         NaN            10-Aug-15          NaN
# 6   13.473374  144.708416             08/10/15  09:01:00 PM
# 7   13.529393  144.870394            12-Aug-15        12:36
# 8   13.530583  144.872400            10-Aug-15         9:30
# 9   13.529850  144.872300            11-Aug-15        20:58
# 10  13.532033  144.873467            12-Aug-15         9:18
# 11  13.474723  144.708906            13-Aug-15          NaN
# 12  13.532250  144.870383            12-Aug-15        10:00
# 13        NaN         NaN             7-Aug-15          NaN
# 14  13.530546  144.870442            11-Aug-15        11:00
# 15  13.529167  144.872683            11-Aug-15        19:31
# 16        NaN         NaN                  NaN          NaN
# 17  13.473946  144.708144            13-Aug-15          NaN
# 18  13.473150  144.708310            11-Aug-15         8:56
# 19  13.473707  144.711533                  NaN          NaN
# 20        NaN         NaN                  NaN          NaN
# 21  13.473160  144.708330            11-Aug-15         8:54
# 22  13.532510  144.871660            12-Aug-15        11:07
# 23  13.471210  144.706360            11-Aug-15          NaN
# 24  13.475751  144.707832                  NaN          NaN
# 25  13.533230  144.873760            12-Aug-15         9:09
# 26  13.474440  144.708450            10-Aug-15          NaN
# 27  13.473650  144.712750            11-Aug-15         9:07
# 28  13.473145  144.708264                  NaN          NaN
# 29        NaN         NaN                  NaN          NaN
# 30  13.529730  144.871570            12-Aug-15        11:43
# 31  13.472615  144.707277             08/13/15  11:20:00 AM
# 32        NaN         NaN                  NaN          NaN
# 33  13.531440  144.871610            11-Aug-15        20:32
#
#     extended_track_bearing end_point_located in_tree breeding_site
# 0                   180.00             False     NaN           NaN
# 1                      NaN              True   False           NaN
# 2                   270.00             False     NaN           NaN
# 3                   270.00             False     NaN           NaN
# 4                      NaN              True    True           NaN
# 5                      NaN             False     NaN           NaN
# 6                   180.00             False     NaN           NaN
# 7                      NaN              True   False           NaN
# 8                      NaN              True    True          True
# 9                   196.44             False     NaN           NaN
# 10                     NaN              True   False           NaN
# 11                     NaN              True   False           NaN
# 12                     NaN              True   False           NaN
# 13                  135.00             False     NaN           NaN
# 14                     NaN              True    True           NaN
# 15                  181.72             False    True           NaN
# 16                  270.00             False     NaN           NaN
# 17                     NaN              True    True           NaN
# 18                     NaN              True    True           NaN
# 19                     NaN              True    True           NaN
# 20                   90.00             False     NaN           NaN
# 21                     NaN              True    True           NaN
# 22                  318.00             False     NaN           NaN
# 23                     NaN              True    True           NaN
# 24                     NaN              True   False          True
# 25                     NaN              True    True           NaN
# 26                  351.03             False   False           NaN
# 27                     NaN              True   False           NaN
# 28                     NaN              True    True           NaN
# 29                     NaN             False     NaN           NaN
# 30                     NaN              True    True           NaN
# 31                  180.00             False    True           NaN
# 32                     NaN               NaN     NaN           NaN
# 33                     NaN              True   False           NaN

# %% [markdown]
# ## Add Morphometrics to Data Set

# %%
df_morphometrics = pd.read_excel('../flight-tested-beetles.xls')
merged_left = pd.merge(left=df_endpoints,right=df_morphometrics, how='left', left_on='beetle_id', right_on='Beetle #')
merged_left.drop(['Beetle #','Outcome','EW','%EW','Area'], axis=1, inplace=True)
merged_left.tail(5)
merged_left.to_csv('merged.csv', index=False)

# %%
merged_left
# Out:
#     beetle_id  frequency rel_site  \
# 0        2968    148.641     Asan
# 1        2977    148.671     Asan
# 2        2991    148.693     Asan
# 3        2981    148.703     Asan
# 4        2971    148.732     Yigo
# 5        2929    148.752      NaN
# 6        2985    148.764     Asan
# 7        2963    148.782     Yigo
# 8        2952    148.792     Yigo
# 9        2978    148.820     Yigo
# 10       2982    148.851     Yigo
# 11       2987    148.873     Asan
# 12       2970    148.873     Yigo
# 13       2931    148.902     Yigo
# 14       2958    148.932     Yigo
# 15       2974    148.963     Yigo
# 16       2976    148.972     Asan
# 17       2962    148.992     Asan
# 18       2980    164.032     Asan
# 19       2989    164.058     Asan
# 20       2951    164.082      NaN
# 21       2967    164.107     Asan
# 22       2972    164.132     Yigo
# 23       2964    164.157     Asan
# 24       2988    164.182     Asan
# 25       2949    164.208     Yigo
# 26       2979    164.232     Asan
# 27       2983    164.258     Asan
# 28       2975    164.282     Asan
# 29       2969    164.307      NaN
# 30       2966    164.333     Yigo
# 31       2965    164.357     Asan
# 32       2944    164.382     Asan
# 33       2973    164.409     Yigo
#
#                                                                                     Notes  \
# 0                              weak signal coming from swamp across from Asan Park; swamp
# 1                                              Found at base of coco tree; just off beach
# 2                                                                     Lost west over hill
# 3                                                           Lost west over hill; no track
# 4                                                          top of coconut tree adjust GPS
# 5                                                                          lost; no track
# 6                                                              out of range; towards road
# 7                                                     under trailer in the dirt; no track
# 8                                                beetle in breadfruit tree; 2952?; wooded
# 9                                                         faint signal in woods; no track
# 10                                              under barrel #12, saw beetle, left beetle
# 11                                                                        base of coconut
# 12  found beetle in soil, transmitter ~20 cm away, retrieved beetle; transmitter reused??
# 13                                        out of range, toward highschool? East; no track
# 14                                             in coconut tree with 6+ bore holes; wooded
# 15                                         edge of dense woods, up high; wooded; no track
# 16                                            Damaged wing, lost west over hill; no track
# 17                                                                            Coconut top
# 18                                                             in damaged coco tree crown
# 19                                                               Same place in coco crown
# 20                                                      Lost east; no coordnates recorded
# 21                                                             in damaged coco tree crown
# 22                                                                  lost into dense brush
# 23                           on top of large coco tree on beach across the hill Asan Park
# 24                                            Found beetl under barrel trap. breedin site
# 25                                        in heavily damaged coco tree over fence; wooded
# 26                                       Lost at indicated coordinates; went out of range
# 27                                                   In or around base of small coco tree
# 28                                                                On top of big coco tree
# 29                                                                                    NaN
# 30                                         In coco tree crown in private property; wooded
# 31                                                        towards tall grass only up high
# 32                                                                      Asan; Did not fly
# 33                                        in brush line around base of small papy; wooded
#
#          lat2        lon2                   d2           t2  \
# 0   13.473933  144.708633            11-Aug-15         9:18
# 1   13.474933  144.708750            11-Aug-15          NaN
# 2   13.472575  144.707141  2015-08-12 19:58:50          NaN
# 3         NaN         NaN                  NaN          NaN
# 4   13.535104  144.873882            12-Aug-15        11:00
# 5         NaN         NaN            10-Aug-15          NaN
# 6   13.473374  144.708416             08/10/15  09:01:00 PM
# 7   13.529393  144.870394            12-Aug-15        12:36
# 8   13.530583  144.872400            10-Aug-15         9:30
# 9   13.529850  144.872300            11-Aug-15        20:58
# 10  13.532033  144.873467            12-Aug-15         9:18
# 11  13.474723  144.708906            13-Aug-15          NaN
# 12  13.532250  144.870383            12-Aug-15        10:00
# 13        NaN         NaN             7-Aug-15          NaN
# 14  13.530546  144.870442            11-Aug-15        11:00
# 15  13.529167  144.872683            11-Aug-15        19:31
# 16        NaN         NaN                  NaN          NaN
# 17  13.473946  144.708144            13-Aug-15          NaN
# 18  13.473150  144.708310            11-Aug-15         8:56
# 19  13.473707  144.711533                  NaN          NaN
# 20        NaN         NaN                  NaN          NaN
# 21  13.473160  144.708330            11-Aug-15         8:54
# 22  13.532510  144.871660            12-Aug-15        11:07
# 23  13.471210  144.706360            11-Aug-15          NaN
# 24  13.475751  144.707832                  NaN          NaN
# 25  13.533230  144.873760            12-Aug-15         9:09
# 26  13.474440  144.708450            10-Aug-15          NaN
# 27  13.473650  144.712750            11-Aug-15         9:07
# 28  13.473145  144.708264                  NaN          NaN
# 29        NaN         NaN                  NaN          NaN
# 30  13.529730  144.871570            12-Aug-15        11:43
# 31  13.472615  144.707277             08/13/15  11:20:00 AM
# 32        NaN         NaN                  NaN          NaN
# 33  13.531440  144.871610            11-Aug-15        20:32
#
#     extended_track_bearing end_point_located in_tree breeding_site  \
# 0                   180.00             False     NaN           NaN
# 1                      NaN              True   False           NaN
# 2                   270.00             False     NaN           NaN
# 3                   270.00             False     NaN           NaN
# 4                      NaN              True    True           NaN
# 5                      NaN             False     NaN           NaN
# 6                   180.00             False     NaN           NaN
# 7                      NaN              True   False           NaN
# 8                      NaN              True    True          True
# 9                   196.44             False     NaN           NaN
# 10                     NaN              True   False           NaN
# 11                     NaN              True   False           NaN
# 12                     NaN              True   False           NaN
# 13                  135.00             False     NaN           NaN
# 14                     NaN              True    True           NaN
# 15                  181.72             False    True           NaN
# 16                  270.00             False     NaN           NaN
# 17                     NaN              True    True           NaN
# 18                     NaN              True    True           NaN
# 19                     NaN              True    True           NaN
# 20                   90.00             False     NaN           NaN
# 21                     NaN              True    True           NaN
# 22                  318.00             False     NaN           NaN
# 23                     NaN              True    True           NaN
# 24                     NaN              True   False          True
# 25                     NaN              True    True           NaN
# 26                  351.03             False   False           NaN
# 27                     NaN              True   False           NaN
# 28                     NaN              True    True           NaN
# 29                     NaN             False     NaN           NaN
# 30                     NaN              True    True           NaN
# 31                  180.00             False    True           NaN
# 32                     NaN               NaN     NaN           NaN
# 33                     NaN              True   False           NaN
#
#    flight_test_date Sex  Length  Width  Weight
# 0        2015-08-10   f   21.17  16.47   2.641
# 1        2015-08-10   f   21.83  16.99   3.622
# 2        2015-08-11   m   25.86  20.63   5.774
# 3        2015-08-10   f   24.94  18.96   5.206
# 4        2015-08-10   m   22.36  17.55   3.087
# 5        2015-08-05   f   25.41  20.29   4.220
# 6        2015-08-10   f   22.80  18.07   4.017
# 7        2015-08-10   m   20.33  16.28   3.179
# 8        2015-08-05   f   24.07  18.67   4.229
# 9        2015-08-10   m   25.22  20.15   5.213
# 10       2015-08-10   m   23.47  18.75   4.672
# 11       2015-08-11   f   23.31  18.31   3.758
# 12       2015-08-10   m   21.60  17.02   3.411
# 13       2015-08-05   m   24.36  18.60   4.367
# 14       2015-08-05   f   25.76  19.16   5.009
# 15       2015-08-10   m   22.59  17.97   3.562
# 16       2015-08-10   m   23.63  18.40   3.803
# 17       2015-08-10   m   26.73  21.19   6.041
# 18       2015-08-10   m   25.96  20.97   5.951
# 19       2015-08-11   m   24.97  19.96   5.329
# 20       2015-08-05   f   24.90  19.14   5.025
# 21       2015-08-10   f   23.40  18.15   4.208
# 22       2015-08-10   f   25.31  19.82   4.433
# 23       2015-08-10   f   24.03  18.71   4.211
# 24       2015-08-11   f   26.41  21.01   6.439
# 25       2015-08-05   m   26.15  20.90   5.942
# 26       2015-08-10   m   24.31  19.01   4.563
# 27       2015-08-10   f   22.07  17.35   4.126
# 28       2015-08-10   m   23.82  18.39   3.910
# 29       2015-08-10   f   24.19  19.10   4.811
# 30       2015-08-10   f   24.01  18.94   4.379
# 31       2015-08-10   f   22.13  17.13   2.989
# 32       2015-08-05   m   22.93  17.73   2.881
# 33       2015-08-10   m   21.25  16.50   3.289
